# %% [markdown]
# ## Exercício 1: Vestibular
#
# Considere que a os dados gerados na célula abaixo contêm o número de acertos de 100 alunos em um vestibular para um curso de exatas, divididas pelos respectivos assuntos. Considere que cada assunto possui um número de questões conforme a tabela abaixo:
#
# | assunto | número de questões |
# |:---:|:---:|
# | Matemática | 24 |
# | Português | 18 |
# | Geografia | 8 |
# | Inglês | 8 |
# | História | 8 |
# | Física | 12 |
# | Química | 12 |
#
# Usando os comandos de operações com DataFrames que você aprendeu na Aula 03, calcule:
#
# 1. (operações com escalar) Calcule o percentual de acerto dos alunos por assunto.
# 2. (operações entre *DataFrames) Calcule o total de acertos de cada aluno.
# 3. Calcule o porcentual geral de cada aluno.
# 4. Suponha que a nota de corte para a segunda fase seja 45. Quantos alunos tiveram nota maior que 45?

# %%
import pandas as pd
import numpy as np

np.random.seed(42)
df_mat = pd.DataFrame(np.random.randint(24, size=(100, 1)), columns=['Qt_acertos_mat'])

df_por = pd.DataFrame(np.random.randint(18, size=(100, 1)), columns=['Qt_acertos_por'])

df_geo = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos_geo'])

df_ing = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos_ing'])

df_his = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos_his'])

df_fis = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos_fis'])

df_qui = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos_qui'])

# %%
# 1) Seu código aqui

# aqui crio uma nova coluna com o total de questoes para cada assunto

df_mat['qtd_questoes_mat'] = 24
df_por['qtd_questoes_por'] = 18
df_geo['qtd_questoes_geo'] = 8
df_ing['qtd_questoes_ing'] = 8
df_his['qtd_questoes_his'] = 8
df_fis['qtd_questoes_fis'] = 12
df_qui['qtd_questoes_qui'] = 12

# agora crio uma terceira coluna, mostrando a porcentagem de acertos de cada aluno, por assunto

df_mat['porc_acertos_mat'] = (df_mat['Qt_acertos_mat'] / df_mat['qtd_questoes_mat']*100).round(2)
df_por['porc_acertos_por'] = (df_por['Qt_acertos_por'] / df_por['qtd_questoes_por']*100).round(2)
df_geo['porc_acertos_geo'] = (df_geo['Qt_acertos_geo'] / df_geo['qtd_questoes_geo']*100).round(2)
df_ing['porc_acertos_ing'] = (df_ing['Qt_acertos_ing'] / df_ing['qtd_questoes_ing']*100).round(2)
df_his['porc_acertos_his'] = (df_his['Qt_acertos_his'] / df_his['qtd_questoes_his']*100).round(2)
df_fis['porc_acertos_fis'] = (df_fis['Qt_acertos_fis'] / df_fis['qtd_questoes_fis']*100).round(2)
df_qui['porc_acertos_qui'] = (df_qui['Qt_acertos_qui'] / df_qui['qtd_questoes_qui']*100).round(2)

# %%
# 2) Seu código aqui

# o codigo abaixo soma todos os acertos por aluno em cada dataframe e mostra isso num novo DataFrame chamado 'total_acertos'

total_acertos = pd.DataFrame(df_mat['Qt_acertos_mat'] + df_por['Qt_acertos_por'] + df_geo['Qt_acertos_geo'] + df_ing['Qt_acertos_ing'] + df_his['Qt_acertos_his'] + df_fis['Qt_acertos_fis'] + df_qui['Qt_acertos_qui'], columns=['total_acertos'])
total_acertos.head()
# Out:
#    total_acertos
# 0             35
# 1             48
# 2             50
# 3             32
# 4             30

# %%
# 3) Seu código aqui

acertos_porcentagem = pd.DataFrame({
    'acertos_porc': (total_acertos['total_acertos'] / 90).round(2)})
acertos_porcentagem.head()
# Out:
#    acertos_porc
# 0          0.39
# 1          0.53
# 2          0.56
# 3          0.36
# 4          0.33

# %%
# 4) Seu código aqui
acima_45 = total_acertos[total_acertos['total_acertos'] > 45]
acima_45.count()
# Out:
# total_acertos    31
# dtype: int64

# %% [markdown]
# ## BONUS

# %%
# no codigo abaixo, combinarei todos os DataFrame criados acima em um unico DataFrame

df_vestibular_total = pd.concat([df_mat, df_por, df_geo, df_ing, df_his, df_fis, df_qui, total_acertos, acertos_porcentagem], axis=1)
df_vestibular_total.head()
# Out:
#    Qt_acertos_mat  qtd_questoes_mat  porc_acertos_mat  Qt_acertos_por  \
# 0               6                24             25.00               7
# 1              19                24             79.17              10
# 2              14                24             58.33              16
# 3              10                24             41.67               7
# 4               7                24             29.17               2
#
#    qtd_questoes_por  porc_acertos_por  Qt_acertos_geo  qtd_questoes_geo  \
# 0                18             38.89               7                 8
# 1                18             55.56               0                 8
# 2                18             88.89               0                 8
# 3                18             38.89               3                 8
# 4                18             11.11               2                 8
#
#    porc_acertos_geo  Qt_acertos_ing  ...  qtd_questoes_his  porc_acertos_his  \
# ...

# %% [markdown]
# ## 2) Vestibular II
#
# Ainda sobre o mesmo banco de dados:
#
# 1. Neste vestibular, quem 'zera' em matemática, física ou química está desqualificado. Monte um novo *DataFrame* com os alunos desqualificados por este critério.
# 2. Quantos são esses alunos?
# 3. Qual a média desses alunos em história e geografia?
# 4. Monte um *DataFrame* com os alunos que passaram para a segunda fase. Repare que estes alunos não podem ter sido desqualificados.

# %%
# seu código aqui

checagem_zero = ['Qt_acertos_mat', 'Qt_acertos_fis', 'Qt_acertos_qui']

df_zero = df_vestibular_total[(
    df_vestibular_total[checagem_zero] == 0).any(axis=1)]

df_zero[['Qt_acertos_mat', 'Qt_acertos_fis', 'Qt_acertos_qui']].head()
# Out:
#     Qt_acertos_mat  Qt_acertos_fis  Qt_acertos_qui
# 3               10               0               8
# 6                6               0               4
# 10              10               7               0
# 12              20               0               3
# 14               7               4               0

# %%
# 2) Quantos são esses alunos?

total_zero = len(df_zero)
total_zero
# Out:
# 23

# %%
# 3) Qual a média desses alunos em história e geografia?

# aqui filtro as notas em historia e geografia de todos os alunos que tiraram zero em pelo menos uma das tres materias (fis, mat, qui)
# guardo essa media em duas variaveis 'media_his' e 'media_geo'
media_his = df_zero['Qt_acertos_his'].mean()
media_geo = df_zero['Qt_acertos_geo'].mean()

# resultados impressos
print(f"Média de Historia: {media_his:.2f}")
print(f"Média de Geografia: {media_geo:.2f}")
# Out:
# Média de Historia: 3.43
# Média de Geografia: 3.22

# %%
# 4) Monte um DataFrame com os alunos que passaram para a segunda fase. Repare que estes alunos não podem ter sido desqualificados.

df_alunos_classificados = df_vestibular_total[(
    df_vestibular_total[checagem_zero] != 0).all(axis=1)]

df_alunos_classificados.head()
# Out:
#    Qt_acertos_mat  qtd_questoes_mat  porc_acertos_mat  Qt_acertos_por  \
# 0               6                24             25.00               7
# 1              19                24             79.17              10
# 2              14                24             58.33              16
# 4               7                24             29.17               2
# 5              20                24             83.33               2
#
#    qtd_questoes_por  porc_acertos_por  Qt_acertos_geo  qtd_questoes_geo  \
# 0                18             38.89               7                 8
# 1                18             55.56               0                 8
# 2                18             88.89               0                 8
# 4                18             11.11               2                 8
# 5                18             11.11               5                 8
#
#    porc_acertos_geo  Qt_acertos_ing  ...  qtd_questoes_his  porc_acertos_his  \
# ...

# %% [markdown]
# ## 3) Vacinações no Acre
# Vamos trabalhar agora com a base de vacinações no Acre. Para facilitar a sua vida, copiamos o link do arquivo na célula abaixo.
#
# 1. Quantas vacinas estão registradas nessa base?
# 2. Quantos pacientes foram vacinados? (considere um paciente para cada valor único de ```paciente_id```)
# 3. Quantos pacientes únicos tomaram a primeira dose? OBS: Há um caractere especial neste campo. Receba os valores do campo com o método ```.unique()```.
# 4. Quantos pacientes com menos de 18 anos foram vacinados?
# 5. Quantos estabelecimentos aplicaram vacina no Acre?
#
#
# **OBS:** O portal do DATASUS pode apresentar instabilidades, retornando um erro na segunda célula abaixo. Por este motivo está disponível uma base estática, que se for baixada para o seu *working directory* pode ser lida com este comando: ```df = pd.read_csv('registros de vacinacao covid ACRE.csv', sep=';')```.
#
# **OBS2:** Para saber qual é o seu working directory, rode no jupyter: ```!pwd```.

# %%
arquivo = 'https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/SIPNI/COVID/uf/uf%3DAC/part-00000-99ea2c53-ce4f-4213-8f90-76846554f1d7.c000.csv'

# %%
df = pd.read_csv(arquivo, sep=';')

# %%
df.head()
# Out:
#                                  document_id  \
# 0  ddf87b8f-1b5e-412a-903d-74d8b747f57f-i0b0
# 1  dd097975-d896-4adc-97a1-5de3f51792a4-i0b0
# 2  b872c769-2fe9-4574-abb5-381283feb543-i0b0
# 3  dd180d26-5bee-44d5-a4d5-ea314976d7f1-i0b0
# 4  ba4d1448-f95c-4448-b30b-b74150280b9d-i0b0
#
#                                          paciente_id  paciente_idade  \
# 0  8a892520bc95e058cf6fe3cbdf6c89273ec8e6f35bd583...              34
# 1  5310f2da2074b4d20620f811323a6f7c4fc8853fc5a41f...              22
# 2  8c76cc84a8139cf123ef97fafb0694cf1dce4816879822...               9
# 3  d0a264fe07e8b95225c45d61cd6f1c020c1dec5d5f1125...              68
# 4  ac787fc50cc03d203f897e03ef557701bc593b1b99ed4a...              33
#
#   paciente_dataNascimento paciente_enumSexoBiologico  paciente_racaCor_codigo  \
# 0              1986-12-23                          M                        1
# 1              1998-08-09                          F                       99
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 390911 entries, 0 to 390910
# Data columns (total 32 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   document_id                               390911 non-null  object
#  1   paciente_id                               390911 non-null  object
#  2   paciente_idade                            390911 non-null  int64
#  3   paciente_dataNascimento                   390911 non-null  object
#  4   paciente_enumSexoBiologico                390911 non-null  object
#  5   paciente_racaCor_codigo                   390911 non-null  int64
#  6   paciente_racaCor_valor                    390911 non-null  object
#  7   paciente_endereco_coIbgeMunicipio         388458 non-null  float64
#  8   paciente_endereco_coPais                  388464 non-null  float64
#  9   paciente_endereco_nmMunicipio             388463 non-null  object
# ...

# %%
# 1) Quantas vacinas estão registradas nessa base?

total_vacinas = df.shape[0]
total_vacinas
# Out:
# 390911

# %%
# 2) Quantos pacientes foram vacinados?

pacientes_vacinados = df['paciente_id'].nunique()
pacientes_vacinados
# Out:
# 318850

# %%
# 3) Quantos pacientes únicos tomaram a primeira dose?

# identifico os diferentes valores na coluna 'vacina_descricao_dose'
dose = df['vacina_descricao_dose'].unique()
dose

# observamos que a '1ª Dose' esta na segunda posicao, ou seja, index = 1
primeira_dose = df['vacina_descricao_dose'].unique()[1]
primeira_dose

# aqui uso a variavel 'primeira_dose' combinada com a funcao loc para encontrar o total de linhas
df['paciente_id'].loc[df['vacina_descricao_dose'] == primeira_dose].nunique()
# Out:
# 143753

# %%
# 4) Quantos pacientes com menos de 18 anos foram vacinados?

df_menor_idade = df[df['paciente_idade'] < 18]
df_menor_idade['paciente_id'].nunique()
# Out:
# 69726

# %%
# 5) Quantos estabelecimentos aplicaram vacina no Acre?

total_estabelecimentos = df['estabelecimento_razaoSocial'].nunique()
total_estabelecimentos
# Out:
# 64

# %% [markdown]
# ## 4) Vacinação II
# Gere um *DataFrame* que contenha somente os estabelecimentos que aplicaram vcinas a menores de 18 anos. Nesse *DataFrame* devem conter somente os dados dos estabelecimentos, mais uma coluna sendo a quantidade de vacinas que o estabelecimento aplicou a menores de 18 anos.
#
# 1. crie uma cópia do *DataFrame* original, contendo somente os registros de vacinas realizadas a menores de 18 anos.
# 2. crie uma lista das colunas desse *DataFrame* com o atributo de *DataFrame* **.columns()**
# 3. Nesse *DataFrame* faça uma contagem do campo ```vacina_categoria_nome```.
# 3. a partir da lista de colunas, escolha somente aquelas que são referentes ao estabelecimento, faça uma lista com esses valores.
# 4. usando o método *.loc*, selecione somente essas variáveis
# 5. Aplique o método **.drop_duplicates** e crie uma lista com uma linha para cada estabelecimento, com os dados do estabelecimento

# %%
# 1) crie uma cópia do DataFrame original, contendo somente os registros de vacinas realizadas a menores de 18 anos.

df_menor_copia = df_menor_idade[df_menor_idade['paciente_idade'] < 18].copy()

# %%
# 2) crie uma lista das colunas desse DataFrame com o atributo de DataFrame .columns()

df_colunas = df_menor_copia.columns

# %%
# 3) Nesse DataFrame faça uma contagem do campo vacina_categoria_nome.

df_menor_copia['vacina_categoria_nome'].count()
# Out:
# np.int64(59044)

# %%
# 4) A partir da lista de colunas, escolha somente aquelas que são referentes ao estabelecimento, faça uma lista com esses valores.

lista_estabelecimento = ['estabelecimento_valor',
       'estabelecimento_razaoSocial', 'estalecimento_noFantasia',
       'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome',
       'estabelecimento_uf']

# 5) usando o método .loc, selecione somente essas variáveis

df_estabelecimento = df_menor_copia.loc[:,lista_estabelecimento]
df_estabelecimento.shape
# Out:
# (79220, 6)

# %%
# 6) Aplique o método .drop_duplicates e crie uma lista com uma linha para cada estabelecimento, com os dados do estabelecimento

estabelecimento_unique = df_estabelecimento.drop_duplicates()
estabelecimento_unique.shape
# Out:
# (213, 6)
